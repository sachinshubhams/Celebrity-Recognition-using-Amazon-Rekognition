# %%
#!pip install boto3
import boto3
import time
import json

# %%
def recognize_celebrities(photo):
    access_key_id='ASIAU42WDA4LCKQITHNH'
    secret_access_key='Tp11femOV7ZUMDoO5J7Bi/c74d6onYZeei4niYCd'
    session_token=''
   
    client=boto3.client('rekognition',aws_access_key_id=access_key_id,aws_secret_access_key=secret_access_key,region_name = 'us-east-1',aws_session_token=session_token)
    with open(photo, 'rb') as image:
        response = client.recognize_celebrities(Image={'Bytes': image.read()})
    print('Detected faces for ' + photo)
    for celebrity in response['CelebrityFaces']:
        print ('Name: ' + celebrity['Name'])
        print ('Id: ' + celebrity['Id'])
        print ('Position:')
        print ('   Left: ' + '{:.2f}'.format(celebrity['Face']['BoundingBox']['Height']))
        print ('   Top: ' + '{:.2f}'.format(celebrity['Face']['BoundingBox']['Top']))
        print ('Info')
        for url in celebrity['Urls']:
            print ('   ' + url)
    return len(response['CelebrityFaces'])

# %%
import os.path
name, extension = os.path.splitext(path)
for i in range(1,11):
    print(recognize_celebrities(name+str(i)+'.jpg'))
# Out:
# Detected faces for Images/Paraguay 01.jpg
# 0
# Detected faces for Images/Paraguay 02.jpg
# 0
# Detected faces for Images/Paraguay 03.jpg
# 0
# Detected faces for Images/Paraguay 04.jpg
# Name: Horacio Cartes
# Id: 2Hk7zm5U
# Position:
#    Left: 0.15
#    Top: 0.34
# Info
#    www.wikidata.org/wiki/Q5901842
# 1
# Detected faces for Images/Paraguay 05.jpg
# 0
# Detected faces for Images/Paraguay 06.jpg
# Name: Francis
# Id: 4E5XN8t
# Position:
#    Left: 0.19
#    Top: 0.22
# Info
#    www.wikidata.org/wiki/Q450675
#    www.imdb.com/name/nm5571029
# Name: J.W. Walsh
# Id: 14y00e
# Position:
#    Left: 0.17
#    Top: 0.58
# Info
#    www.wikidata.org/wiki/Q17715112
# Name: Francis
# Id: 4E5XN8t
# Position:
#    Left: 0.16
#    Top: 0.27
# Info
#    www.wikidata.org/wiki/Q450675
#    www.imdb.com/name/nm5571029
# 3
# Detected faces for Images/Paraguay 07.jpg
# Name: D. Todd Christofferson
# Id: 4dl8yf5i
# Position:
#    Left: 0.23
#    Top: 0.17
# Info
# ...
